# %%
import pandas as pd
df1=pd.read_csv("C:\\Users\\jayde\\Downloads\\drinks.csv") 
df1
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
x =df1.groupby("continent")
x.first()
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# continent
# AF             Algeria             25                0             14
# AS         Afghanistan              0                0              0
# EU             Albania             89              132             54
# OC           Australia            261               72            212
# SA           Argentina            193               25            221
#
#            total_litres_of_pure_alcohol
# continent
# AF                                  0.7
# AS                                  0.0
# EU                                  4.9
# OC                                 10.4
# SA                                  8.3

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 get.groupby("country")
#
# NameError: name 'get' is not defined

# %%
var =df1.groupby(["continent","country"])
var.first()
# Out:
#                         beer_servings  spirit_servings  wine_servings  \
# continent country
# AF        Algeria                  25                0             14
#           Angola                  217               57             45
#           Benin                    34                4             13
#           Botswana                173               35             35
#           Burkina Faso             25                7              7
# ...                               ...              ...            ...
# SA        Paraguay                213              117             74
#           Peru                    163              160             21
#           Suriname                128              178              7
#           Uruguay                 115               35            220
#           Venezuela               333              100              3
#
#                         total_litres_of_pure_alcohol
# continent country
# ...

# %%
df1.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
df1.groupby("continent").sum()
# Out:
#                                                      country  beer_servings  \
# continent
# AF         AlgeriaAngolaBeninBotswanaBurkina FasoBurundiC...           3258
# AS         AfghanistanBahrainBangladeshBhutanBruneiCambod...           1630
# EU         AlbaniaAndorraArmeniaAustriaAzerbaijanBelarusB...           8720
# OC         AustraliaCook IslandsFijiKiribatiMarshall Isla...           1435
# SA         ArgentinaBoliviaBrazilChileColombiaEcuadorGuya...           2101
#
#            spirit_servings  wine_servings  total_litres_of_pure_alcohol
# continent
# AF                     866            862                         159.4
# AS                    2677            399                          95.5
# EU                    5965           6400                         387.8
# OC                     935            570                          54.1
# SA                    1377            749                          75.7

# %%
df1.groupby("continent").agg({"beer_servings":["sum","mean"]})
# Out:
#           beer_servings
#                     sum        mean
# continent
# AF                 3258   61.471698
# AS                 1630   37.045455
# EU                 8720  193.777778
# OC                 1435   89.687500
# SA                 2101  175.083333

# %%
df1.groupby("continent").agg({"beer_servings":["sum","mean","min","max","count"]})
# Out:
#           beer_servings
#                     sum        mean min  max count
# continent
# AF                 3258   61.471698   0  376    53
# AS                 1630   37.045455   0  247    44
# EU                 8720  193.777778   0  361    45
# OC                 1435   89.687500   0  306    16
# SA                 2101  175.083333  93  333    12

# %%
x.get_group("AS").head(22)
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 12       Bahrain             42               63              7
# 13    Bangladesh              0                0              0
# 19        Bhutan             23                0              0
# 24        Brunei             31                2              1
# 30      Cambodia             57               65              1
# 36         China             79              192              8
# 46   North Korea              0                0              0
# 77         India              9              114              0
# 78     Indonesia              5                1              0
# 79          Iran              0                0              0
# 80          Iraq              9                3              0
# 82        Israel             63               69              9
# 85         Japan             77              202             16
# ...
