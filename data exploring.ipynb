# %%
import pandas as pd 
df1=pd.read_csv("C:\\Users\\jayde\\Downloads\\loan-test.csv")
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %%
df1.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
df1.head(10)
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001015    Male     Yes          0      Graduate            No
# 1  LP001022    Male     Yes          1      Graduate            No
# 2  LP001031    Male     Yes          2      Graduate            No
# 3  LP001035    Male     Yes          2      Graduate            No
# 4  LP001051    Male      No          0  Not Graduate            No
# 5  LP001054    Male     Yes          0  Not Graduate           Yes
# 6  LP001055  Female      No          1  Not Graduate            No
# 7  LP001056    Male     Yes          2  Not Graduate            No
# 8  LP001059    Male     Yes          2      Graduate           NaN
# 9  LP001067    Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# ...

# %%
df1.tail(10)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 357  LP002952    Male      No          0      Graduate            No
# 358  LP002954    Male     Yes          2  Not Graduate            No
# 359  LP002962    Male      No          0      Graduate            No
# 360  LP002965  Female     Yes          0      Graduate            No
# 361  LP002969    Male     Yes          1      Graduate            No
# 362  LP002971    Male     Yes         3+  Not Graduate           Yes
# 363  LP002975    Male     Yes          0      Graduate            No
# 364  LP002980    Male      No          0      Graduate            No
# 365  LP002986    Male     Yes          0      Graduate            No
# 366  LP002989    Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 357             2500                  0        60.0             360.0
# ...

# %%
print(df1["Loan_ID"].duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 362    False
# 363    False
# 364    False
# 365    False
# 366    False
# Name: Loan_ID, Length: 367, dtype: bool

# %%
df1.drop_duplicates("Loan_ID")
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df1.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
df1.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome      int64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# dtype: object

# %%
df1.describe(include="object")
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        367    356     367        357       367           344
# unique       367      2       2          4         2             2
# top     LP002989   Male     Yes          0  Graduate            No
# freq           1    286     233        200       283           307
#
#        Property_Area
# count            367
# unique             3
# top            Urban
# freq             140

# %%
df1["Self_Employed"].value_counts()
# Out:
# Self_Employed
# No     307
# Yes     37
# Name: count, dtype: int64

# %%
df1["Self_Employed"].value_counts(normalize=True)*100
# Out:
# Self_Employed
# No     89.244186
# Yes    10.755814
# Name: proportion, dtype: float64

# %%
df1["Self_Employed"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Self_Employed'>

# %%
df1["Gender"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df1.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome      int64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# dtype: object

# %%
import matplotlib.pyplot  as plt 
import seaborn as sns 
df_cr =df1.select_dtypes(["float64","int64"]).corr()
df_cr
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.110335    0.493451
# CoapplicantIncome        -0.110335           1.000000    0.150850
# LoanAmount                0.493451           0.150850    1.000000
# Loan_Amount_Term          0.023249          -0.010984    0.094950
# Credit_History            0.099553          -0.071235   -0.012578
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome            0.023249        0.099553
# CoapplicantIncome         -0.010984       -0.071235
# LoanAmount                 0.094950       -0.012578
# Loan_Amount_Term           1.000000       -0.053593
# Credit_History            -0.053593        1.000000

# %%
plt.figure(figsize=(4,3))
sns.heatmap(df_cr,annot=True)
plt.show()

# %%
df_cov =df1.select_dtypes(["float64","int64"]).cov()
df_cov
# Out:
#                    ApplicantIncome  CoapplicantIncome     LoanAmount  \
# ApplicantIncome       2.411483e+07      -1.264732e+06  148734.535560
# CoapplicantIncome    -1.264732e+06       5.448639e+06   21651.040082
# LoanAmount            1.487345e+05       2.165104e+04    3765.866026
# Loan_Amount_Term      7.480427e+03      -1.677670e+03     381.136129
# Credit_History        1.830351e+02      -6.177107e+01      -0.279623
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome         7480.427455      183.035125
# CoapplicantIncome      -1677.669852      -61.771074
# LoanAmount               381.136129       -0.279623
# Loan_Amount_Term        4245.388181       -1.360668
# Credit_History            -1.360668        0.144514

# %%
plt.figure(figsize=(6,6))
sns.heatmap(df_cov,annot=True)
plt.show()

# %%
plt.figure(figsize=(5,4))
df1.boxplot(column="ApplicantIncome",by="Education")
# Out:
# <Axes: title={'center': 'ApplicantIncome'}, xlabel='Education'>
